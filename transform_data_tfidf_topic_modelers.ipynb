# %% [markdown]
# ### transform_data_tfidf_topic_modelers
#
# * transform tokenized text to word matrix using tfidf vectorizer
# * build 3 topic modlers: lsa, lda and nmf

# %%
import pymongo
from pymongo import MongoClient
import datetime
import pickle
import nltk
import re
import time
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer


# %matplotlib inline
plt.style.use('seaborn')

# %% [markdown]
# #### generate a sample from tokenized presidential document collection

# %%
client = MongoClient()
db = client.test_database
presidency_docs_stem = db.presidency_docs_stem
cursor = presidency_docs_stem.find({})

records = [record for record in cursor]
docs = [records[i]['stem_text'] for i in range(len(records))]
authors = [records[i]['author'] for i in range(len(records))]
titles = [records[i]['title'] for i in range(len(records))]
dates = [records[i]['date'] for i in range(len(records))]

# %%
# unique authors in the presidential document collection
# includes presidetnts, vice presidents, presidential candidates, 
# house/senate speakers, state secretaries, first ladies, etc.

print(set(authors))
# Out:
# {'William Henry Harrison', 'Wendell Willkie', 'Michael S. Dukakis', 'Lindsey Graham', 'Abraham Lincoln', 'John Anderson', 'Robert Gibbs', 'Republican Party Platforms', 'Bernie Sanders', 'Herbert Hoover', 'Scott McClellan', 'Scott Walker', 'John Tyler', 'Walter F. Mondale', 'George Bush', 'Harry S. Truman', 'Laura Bush', 'Chris Christie', 'John Kasich', 'Andrew Johnson', 'John McCain', 'Sean Spicer', 'Donald J. Trump', 'Joe Biden', 'Franklin D. Roosevelt', 'Jack Kemp', 'Newt Gingrich', 'Bill Richardson', 'Tony Snow', 'Christopher Dodd', 'Barack Obama', 'Jay Carney', 'Franklin Pierce', 'Gerald R. Ford', 'Lincoln Chafee', 'George W. Bush', 'Sarah Huckabee Sanders', 'Herman Cain', 'Melania Trump', 'Ari Fleischer', 'Bobby Jindal', 'H. Ross Perot', 'Marco Rubio', 'U.S. Congress', 'George Washington', 'Ulysses S. Grant', 'Michelle Obama', 'Theodore Roosevelt', 'Hillary Clinton', 'Thomas Jefferson', 'James K. Polk', 'Andrew Jackson', 'George Pataki', 'Grover Cleveland', 'Barry Goldwater', 'Rick Perry', 'William Howard Taft', 'Josh Earnest', 'Ben Carson', 'Dwight D. Eisenhower', 'Joseph Lieberman', 'Mike Huckabee', 'Jon Huntsman', 'Rand Paul', 'Minor/Third Party Platforms', 'William McKinley', 'Jim Webb', 'George McGovern', 'Hubert H. Humphrey', 'Ted Cruz', "Martin O'Malley", 'Fred Thompson', 'Richard B. Cheney', 'Lyndon B. Johnson', 'Albert Gore, Jr.', 'Patrick J. Buchanan', 'James Buchanan', 'Michele Bachmann', 'Woodrow Wilson', 'Adlai Stevenson', 'Rutherford B. Hayes', 'Al Smith', 'Warren G. Harding', 'Mike Pence', 'Democratic Party Platforms', 'Paul Ryan', 'Jimmy Carter', 'Chester A. Arthur', 'Carly Fiorina', 'Martin van Buren', 'John F. Kerry', 'Calvin Coolidge', 'William J. Clinton', 'Sarah Palin', 'John Adams', 'John Quincy Adams', 'Thomas Dewey', 'Millard Fillmore', 'Ron Paul', 'Robert Dole', 'John Edwards', 'Jeb Bush', 'Dana Perino', 'Benjamin Harrison', 'Presidential Candidates Debates', 'Rudy Giuliani', 'Charles E. Hughes', 'Richard Nixon', 'James Monroe', 'Zachary Taylor', 'James Madison', 'James A. Garfield', 'Ronald Reagan', 'John F. Kennedy', 'Mitt Romney', 'Tim Pawlenty', 'Tim Kaine', 'Rick Santorum'}

# %%
presidents=['Donald J. Trump','Richard Nixon','John Adams','Lyndon B. Johnson','Dwight D. Eisenhower','Woodrow Wilson','Abraham Lincoln',
 'John F. Kennedy','George W. Bush','Grover Cleveland','William J. Clinton','Franklin D. Roosevelt','James Madison','Ulysses S. Grant','Barack Obama','William Howard Taft',
 'Andrew Jackson',
 'George Bush',
 'Ronald Reagan',
 'Harry S. Truman',
 'Gerald R. Ford','Herbert Hoover','George Washington','William Henry Harrison','Jimmy Carter','Warren G. Harding','Thomas Jefferson','Theodore Roosevelt']

# %%
# lastest presidents
latest_presidents = ['Donald J. Trump','Barack Obama','George W. Bush']
latest_presidents_docs = []
latest_presidents_authors=[]
for i in range(len(authors)):
    if authors[i] in latest_presidents:
        latest_presidents_authors.append(authors[i])
        latest_presidents_docs.append(docs[i])

# %%
# generate sample of all docs 
import random
sample_size = 30000

sample_docs_indices = sorted(random.sample(range(len(docs)), sample_size))
sample_docs = [docs[i] for i in sample_docs_indices]
sample_authors = [authors[i] for i in sample_docs_indices]

# %% [markdown]
# #### transform tokenized text to word matrix.
# #### choose tfidf over count vectorizer to give earlier presidential documents a fair weight because modern presidents have lots more documents than the earlier ones.

# %%
# documents have already been cleaned, lowercased, tokenized and stored in database
# earlier to speed up the computation of tfidf vectorizer. So here no need to repeat
# these steps.
sample_tfidf_vectorizer = TfidfVectorizer(ngram_range=(1, 2),  
                                   max_features=5000, 
                                   token_pattern="\\b[a-z][a-z]+\\b",
                                   # documents have already been
                                   # lowercased
                                   lowercase=False,
                                   max_df = 0.6)

# %%
gen = (sample_docs[i] for i in range(len(sample_docs)))
sample_tfidf_data = sample_tfidf_vectorizer.fit_transform(gen)

# %% [markdown]
# #### build topic modelers (nmf, lsa, lda) ;  save them and transformed data in 200 topic space in pickle files

# %%
from sklearn.decomposition import NMF, TruncatedSVD
n_comp = 200
#lsa_tfidf = TruncatedSVD(n_components=n_comp)
sample_nmf_tfidf = NMF(n_components=n_comp)

#lsa_tfidf_data = lsa_tfidf.fit_transform(tfidf_data)
sample_nmf_tfidf_data = sample_nmf_tfidf.fit_transform(sample_tfidf_data)

# %%
filename = '/home/ubuntu/proj4/data/sample_30000_nmf_200_tfidf_data_5000.pkl'
pickle.dump((sample_nmf_tfidf, sample_nmf_tfidf_data), open(filename, 'wb'))

# %%
sample_lsa_tfidf = TruncatedSVD(n_components=n_comp)
sample_lsa_tfidf_data = sample_lsa_tfidf.fit_transform(sample_tfidf_data)

# %%
filename = '/home/ubuntu/proj4/data/sample_30000_lsa_200_tfidf_data_5000.pkl'
pickle.dump((sample_lsa_tfidf, sample_lsa_tfidf_data), open(filename, 'wb'))

# %%
from sklearn.decomposition import LatentDirichletAllocation

n_iter = 10
sample_lda_tfidf = LatentDirichletAllocation(n_topics=n_comp,
                                max_iter=n_iter,
                                random_state=42,
                               learning_method='online')
sample_lda_tfidf_data = sample_lda_tfidf.fit_transform(sample_tfidf_data)
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/decomposition/online_lda.py:294: DeprecationWarning: n_topics has been renamed to n_components in version 0.19 and will be removed in 0.21
#   DeprecationWarning)

# %%
filename = '/home/ubuntu/proj4/data/sample_30000_lda_200_tfidf_data_5000.pkl'
pickle.dump((sample_lda_tfidf, sample_lda_tfidf_data), open(filename, 'wb'))

# %%
#sample_lda_tfidf.transform(sample_tfidf_data[100:102,])

# %%
sample_nmf_tfidf_data.size
# Out:
# 6000000

# %%
def display_topics(model, feature_names, no_top_words, topic_names=None):
    
    for ix, topic in enumerate(model.components_):
        if not topic_names or not topic_names[ix]:
            print("\nTopic ", ix)
        else:
            print("\nTopic: '",topic_names[ix],"'")
        print(", ".join([feature_names[i]
                        for i in topic.argsort()[:-no_top_words - 1:-1]]))

# %%
display_topics(sample_nmf_tfidf,sample_tfidf_vectorizer.get_feature_names(),10)
# Out:
# Topic  0
# know, tell, come, friend, time, great, know know, understand, want know, like
#
# Topic  1
# united states, states, united, president united, states government, people united, citizen united, person, states america, jurisdiction
#
# Topic  2
# assistant, assistant secretary, affairs, deputy, assistant president, deputy assistant, special assistant, special, serve, legislative
#
# Topic  3
# program, assistance, development, grant, assistance program, training, provide, increase, develop, area
#
# Topic  4
# problem, present, conference, question, make, time, power, matter, action, great
#
# Topic  5
# administration support, administration, statement administration, administration policy, statement, enactment, support, policy, policy administration, passage
#
# Topic  6
# house representatives, representatives, house, senate house, letter, copy, communicate, andrew, subject, transmit
#
# Topic  7
# funding available, federal, share basis, cost share, fema, federal funding, funding, recovery, damage, storm
#
# Topic  8
# administration, statement administration, administration policy, objection, statement, enactment, policy, policy administration, passage, administration oppose
#
# Topic  9
# world, world war, people world, free, new, free world, today, nation world, great, century
#
# Topic  10
# iowa, moines, des, des moines, caucus, campaign, biden, poll, huckabee, marco
#
# Topic  11
# job, worker, economy, create, create job, unemployment, new job, new, million, manufacturing
#
# Topic  12
# shall, order, sec, order shall, function, prescribe, person, regulation, department agency, duty
#
# Topic  13
# district, states district, states attorney, district judge, attorney, district court, southern, marshal, year vice, term year
#
# Topic  14
# terrorist, attack, terror, terrorism, enemy, threat, september, terrorist attack, al, war terror
#
# Topic  15
# emergency, national emergency, continue effect, federal register, declare, continue, emergency declare, register, notice, national
#
# Topic  16
# minister, prime minister, prime, president prime, visit, india, canada, discussion, welcome, australia
#
# Topic  17
# section, section act, pursuant, pursuant section, act, subsection, act section, waiver, respect, provision
#
# Topic  18
# reside, married, married child, child reside, announce intention, bear, president today, today announce, graduate, intention
#
# Topic  19
# reagan, ronald reagan, ronald, reagan president, eighty, week, president reagan, issue proclamation, joint resolution, observance
#
# Topic  20
# health, care, health care, insurance, coverage, health insurance, medicare, cost, medical, plan
#
# Topic  21
# mccurry, mike, mccurry think, mccurry president, issue, discussion, address, question, talk, mccurry know
#
# Topic  22
# education, educational, teacher, department education, high education, training, quality, secondary, excellence, health education
#
# Topic  23
# romney, mitt, mitt romney, governor romney, massachusetts, conservative, follow statement, president obama, boston, republican
#
# Topic  24
# resolution, report secretary, instant, report, accompany, transmit, secretary state, compliance, request, document
#
# Topic  25
# man, great, life, come, man woman, honor, young, old, good, friend
#
# Topic  26
# japan, japanese, pacific, asia, asian, ambassador, asia pacific, market, islands, philippines
#
# Topic  27
# international, development, organization, foreign, international development, policy, international trade, international community, monetary, cooperation
#
# Topic  28
# state, secretary state, department state, local, state local, state department, michigan, legislature, state university, union
#
# Topic  29
# obama, president obama, barack, barack obama, senator obama, obama say, obama president, campaign, president barack, follow statement
#
# Topic  30
# economic, economy, growth, market, financial, economic growth, policy, investment, recovery, reform
#
# Topic  31
# ambassador, plenipotentiary, ambassador extraordinary, extraordinary plenipotentiary, plenipotentiary united, foreign service, extraordinary, career member, member senior, senior foreign
#
# Topic  32
# atomic, atomic energy, energy, cooperation, propose, peaceful, power, material, nuclear, uranium
#
# Topic  33
# nuclear, weapon, nuclear weapon, proliferation, chemical, missile, control, test, material, nonproliferation
#
# Topic  34
# hillary, clinton, hillary clinton, senator clinton, campaign, president clinton, endorsement, candidate, read, supporter
#
# Topic  35
# tax, cut, income, tax cut, income tax, plan, tax relief, relief, revenue, rate
#
# Topic  36
# energy, clean, renewable, department energy, ga, efficiency, fuel, solar, energy policy, conservation
#
# Topic  37
# award, medal, honor, art, gold, distinguished, present, contribution, music, recipient
#
# Topic  38
# crime, gun, violence, criminal, police, victim, enforcement, law enforcement, violent, justice
#
# Topic  39
# university, professor, state university, associate, serve, graduate, receive, institute, harvard, college
#
# Topic  40
# president intend, serve, intend nominate, nominate, intend, degree, bachelor, bachelor degree, currently serve, currently
#
# Topic  41
# peace, middle east, east, middle, peace process, peace corps, hope, process, achieve, world peace
#
# Topic  42
# farm, farmer, agriculture, agricultural, rural, price, crop, wheat, production, surplus
#
# Topic  43
# board, member board, chairman, board directors, directors, corporation, board shall, bank, advisory board, broadcasting
#
# Topic  44
# want, want thank, want say, come, want know, believe, just want, want make, ask, people want
#
# Topic  45
# freedom, free, democracy, liberty, struggle, independence, stand, tyranny, democratic, society
#
# Topic  46
# order, executive order, executive, property, sec, revoke, pursuant, person, order shall, authority
#
# Topic  47
# mcclellan, talk, mcclellan think, scott, forward, look, continue, question, address, war terrorism
#
# Topic  48
# commission, chairman, recommendation, appoint, commissioner, study, appointment, regulatory, civil, establish
#
# Topic  49
# general, attorney, attorney general, counsel, justice, department justice, general counsel, army, states attorney, command
#
# Topic  50
# israel, palestinian, israeli, middle east, jewish, east, egypt, palestinians, middle, israelis
#
# Topic  51
# term expire, expire, term, vice, member, member national, term year, resign, remainder, year vice
#
# Topic  52
# president bush, bush, talk, issue, thank president, discuss, sir, question, gorbachev, look forward
#
# Topic  53
# george, george bush, bush, sincerely, president george, bush president, dear, speaker, george washington, thousand independence
#
# Topic  54
# gibbs, gibbs think, think, obviously, robert, talk, look, think president, yes, know
#
# Topic  55
# york, new york, new, york city, jersey, new jersey, times, york times, harvard, bear
#
# Topic  56
# public law, public, law, law act, approve, appropriations, september, joint resolution, purpose, april
#
# Topic  57
# business, small business, small, owner, business owner, business administration, entrepreneur, company, minority, loan
#
# Topic  58
# paul, ron paul, ron, town hall, presidential, candidate, hall, texas, presidential candidate, campaign
#
# Topic  59
# fleischer, ari, fleischer president, fleischer think, question, saddam, saddam hussein, meeting, hussein, talk
#
# Topic  60
# vote, election, voter, win, poll, audience, voting, audience member, opponent, democrats
#
# Topic  61
# township, west, east, corner, south, north, range, corner section, say township, section
#
# Topic  62
# congress, legislation, pass, enact, action, legislative, veto, sign, need, proposal
#
# Topic  63
# committee, advisory committee, advisory, chairman, subcommittee, representative, house, serve, inspection, chair
#
# Topic  64
# budget, deficit, spending, billion, cut, balanced, balanced budget, balance, balance budget, reduction
#
# Topic  65
# trump, donald trump, donald, president trump, president elect, elect, republican, poll, make america, spicer
#
# Topic  66
# vice, vice president, resign, term year, president vice, year vice, cheney, biden, manager, chairman
#
# Topic  67
# edwards, john, follow statement, release, north carolina, follow, statement, carolina, north, hill
#
# Topic  68
# drug, abuse, drug abuse, use, treatment, enforcement, alcohol, prescription, colombia, illegal
#
# Topic  69
# china, chinese, republic china, taiwan, relationship, people republic, asia, visit, relation, export
#
# Topic  70
# press, press secretary, press briefing, briefing, secretary, mike, release, dee, sheet, print
#
# Topic  71
# year, ago, year ago, time, new, past, year year, past year, make, million
#
# Topic  72
# mexico, new mexico, richardson, mexican, border, immigration, new, nafta, santa, hispanic
#
# Topic  73
# nations, united nations, united, general assembly, assembly, representative, secretary general, charter, general, security council
#
# Topic  74
# lebanon, lebanese, syria, syrian, refugee, hostage, force, sovereignty, support, middle east
#
# Topic  75
# work, hard, hard work, forward, work hard, continue, look forward, forward work, continue work, look
#
# Topic  76
# hampshire, new hampshire, new, voter, town, primary, campaign, poll, town hall, candidate
#
# Topic  77
# lockhart, lockhart think, joe, think, talk, know, issue, think president, process, look
#
# Topic  78
# carney, jay, carney think, question, issue, just, clear, obviously, say, talk
#
# Topic  79
# social security, social, security, medicare, retirement, benefit, senior, old, worker, age
#
# Topic  80
# county, chair, florida, republican, representative, leader, owner, commissioner, business owner, chairman
#
# Topic  81
# court, justice, supreme court, supreme, judge, judicial, appeals, district court, nominee, legal
#
# Topic  82
# treaty, ratification, advice consent, consent, advice, sign, conclude, article, investment, mutual
#
# Topic  83
# nato, europe, alliance, european, atlantic, allies, kosovo, germany, security, chancellor
#
# Topic  84
# korea, north, north korea, korean, republic korea, peninsula, kim, south korea, koreans, north koreans
#
# Topic  85
# iraq, iraqi, troop, iraqis, iraqi people, saddam, force, saddam hussein, hussein, coalition
#
# Topic  86
# judge, circuit, district judge, retire, nomination, states district, vice, appeals, new jersey, jersey
#
# Topic  87
# earnest, josh, isil, certainly, earnest think, kind, just, republicans, syria, try
#
# Topic  88
# cooperation, meeting, issue, bilateral, region, leader, partnership, relationship, discuss, security
#
# Topic  89
# senate, senate united, andrew, transmit, copy, consideration, communicate, ratification, letter, senate house
#
# Topic  90
# people, american people, people united, young, young people, life, future, million people, people people, people country
#
# Topic  91
# government, federal government, federal, private, government united, local, states government, citizen, local government, public
#
# Topic  92
# myers, dee, myers think, dee dee, meeting, certainly, haiti, schedule, package, plan
#
# Topic  93
# just, kid, like, folk, right, let, young, tell, day, guy
#
# Topic  94
# say, tell, let, make, word, president say, just, let say, say say, speech
#
# Topic  95
# dole, bob, medium, travel, attend, october, local, photo, airport, friday
#
# Topic  96
# mccain, john mccain, john, va, presidential campaign, senator mccain, campaign, presidential, florida, town hall
#
# Topic  97
# soviet, soviet union, union, arm, gorbachev, soviets, missile, reduction, arm control, negotiation
#
# Topic  98
# red cross, red, cross, disaster, relief, blood, volunteer, flood, victim, organization
#
# Topic  99
# nation, great, future, common, great nation, citizen, challenge, strength, share, commitment
#
# Topic  100
# national, national security, security, park, national park, member national, president national, guard, national defense, national guard
#
# Topic  101
# thank, want thank, appreciate, come, good, great, welcome, thank president, honor, thank thank
#
# Topic  102
# vietnam, vietnamese, south, johnson, enemy, asia, miss, communist, lyndon, lyndon johnson
#
# Topic  103
# child, parent, child care, care, mother, children, adoption, young, life, childhood
#
# Topic  104
# administration official, senior administration, official, senior, administration, issue, discussion, meeting, talk, process
#
# Topic  105
# emergency, assistance, federal, fema, homeland security, federal emergency, homeland, emergency management, department homeland, management agency
#
# Topic  106
# governor, governor romney, richardson, florida, huckabee, governors, candidate, arkansas, romney, washington
#
# Topic  107
# transportation, safety, highway, department transportation, secretary transportation, infrastructure, rail, aviation, transit, traffic
#
# Topic  108
# pension, claim, beneficiary, entitle, cleveland, approval, discharge, return, grant, file
#
# Topic  109
# republic, federal republic, people republic, chancellor, german, germany, republic china, waiver, trade act, subsection
#
# Topic  110
# veteran, veterans, va, veterans affairs, serve, service, benefit, affairs, care, disabled
#
# Topic  111
# food, million, safety, hunger, agriculture, agricultural, supply, nutrition, need, aid
#
# Topic  112
# america, strong, states america, believe, americans, future, stand, build, best, dream
#
# Topic  113
# director, office, director office, management, deputy director, executive director, office management, deputy, executive, management budget
#
# Topic  114
# cruz, ted, texas, conservative, houston, campaign, candidate, endorsement, grassroots, fight
#
# Topic  115
# giuliani, rudy, mayor, florida, chair, thompson, campaign, presidential, republican, leadership
#
# Topic  116
# perino, dana, talk, just, think, know, question, say, meeting, yesterday
#
# Topic  117
# housing, mortgage, urban, home, housing urban, urban development, development, loan, homeowner, bank
#
# Topic  118
# percent, rate, increase, inflation, price, unemployment, wage, cost, high, low
#
# Topic  119
# majesty, king, friendship, visit, luther, martin, welcome, great, kingdom, saudi
#
# Topic  120
# country, great, visit, welcome, come, people country, hope, develop country, great country, develop
#
# Topic  121
# trade, trade agreement, export, free trade, free, market, trade act, international trade, world trade, section trade
#
# Topic  122
# agreement, trade agreement, sign, negotiation, reach, extend, negotiate, exchange, accordance, favorable
#
# Topic  123
# defense, secretary defense, department defense, national defense, missile, strategic, security, missile defense, arms, military
#
# Topic  124
# amend, act amend, section, vest, authority vest, delete, insert, thereof, vest section, paragraph
#
# Topic  125
# senator, senator obama, campaign, senator clinton, congressman, kennedy, representative, senator kennedy, leader, clinton
#
# Topic  126
# thing, lot, good, try, way, talk, like, money, big, problem
#
# Topic  127
# think, question, just, try, talk, feel, president think, yes, sir, answer
#
# Topic  128
# iran, iranian, sanction, november, hostage, deal, iran nuclear, claim, iranians, nuclear program
#
# Topic  129
# administration, fund, funding, fy, request, provision, million, administration strongly, provide, strongly
#
# Topic  130
# oil, price, ga, production, import, fuel, crude, supply, consumer, petroleum
#
# Topic  131
# ireland, irish, northern ireland, northern, patrick, british, violence, britain, heritage, blair
#
# Topic  132
# woman, man woman, women, girl, mother, equal, man, equality, violence, opportunity
#
# Topic  133
# convention, ratification, advice consent, consent, protocol, advice, sign, consideration, transmit, department state
#
# Topic  134
# american, american people, americans, american citizen, inter, native, history, african american, american worker, american history
#
# Topic  135
# sanders, campaign, bernie, sander, clinton, wall street, wall, debate, presidential, street
#
# Topic  136
# family, home, love, life, military family, american family, care, parent, family member, sympathy
#
# Topic  137
# student, college, young, loan, young people, high, student loan, community college, high education, graduate
#
# Topic  138
# city, mayor, york city, urban, kansas, washington, orleans, new orleans, chicago, building
#
# Topic  139
# cuba, cuban, castro, democracy, regime, island, hemisphere, transition, solidarity, democratic
#
# Topic  140
# secretary, secretary state, treasury, secretary treasury, assistant secretary, secretary commerce, secretary defense, commerce, secretary agriculture, secretary interior
#
# Topic  141
# water, environmental, river, project, resource, protection, conservation, pollution, clean, environment
#
# Topic  142
# science, research, technology, scientific, science technology, national science, engineering, development, scientist, research development
#
# Topic  143
# officer, chief, deputy, foreign service, affairs, foreign, deputy chief, political, bureau, mission
#
# Topic  144
# school, teacher, student, high school, high, school district, public school, classroom, kid, grade
#
# Topic  145
# cancer, disease, research, treatment, awareness, health, prevention, cure, medical, heart
#
# Topic  146
# military, armed, forces, armed forces, force, personnel, commander, operation, army, support
#
# Topic  147
# climate, climate change, change, emission, global, carbon, clean, greenhouse, reduce, technology
#
# Topic  148
# agency, federal, employee, department agency, federal government, management, federal agency, memorandum, executive, head
#
# Topic  149
# columbia, district columbia, district, superior, resign, term year, washington, reorganization, year vice, associate
#
# Topic  150
# disability, americans, employment, opportunity, individual, equal, discrimination, access, barrier, disabled
#
# Topic  151
# member, advisory, appoint, serve, member president, follow individual, announce intent, member national, appointment, advisory committee
#
# Topic  152
# welfare, reform, welfare reform, welfare work, recipient, people welfare, education welfare, responsibility, health education, poverty
#
# Topic  153
# pay, estimate, omb, receipt, requirement, reconciliation, preliminary, increase, employee, salary
#
# Topic  154
# human, right, human right, rights, human rights, civil, declaration, universal, civil right, life
#
# Topic  155
# party, republican, democratic, republican party, democratic party, candidate, campaign, republicans, political, democrats
#
# Topic  156
# intelligence, information, intelligence community, foreign, security, intelligence agency, national security, central, agency, cia
#
# Topic  157
# make, make sure, sure, need, everybody, able, progress, folk, decision, understand
#
# Topic  158
# states america, president united, day, proclamation, america, year lord, witness whereof, whereof hereunto, hereunto set, set hand
#
# Topic  159
# class, middle class, middle, cut, deficit, class family, americans, tax cut, plan, middle east
#
# Topic  160
# proclamation, article, import, tariff, annex, duty, hts, section trade, beneficiary, modify
#
# Topic  161
# africa, african, south africa, south, continent, nigeria, development, aids, african american, black
#
# Topic  162
# navy, marine, naval, corps, army, marine corps, admiral, coast, commander, ship
#
# Topic  163
# flag, vessel, naval, fly, building, facility, staff, half, station, day
#
# Topic  164
# fiscal, fiscal year, appropriation, year, expenditure, authorization, million, estimate, fund, national defense
#
# Topic  165
# andwhereas, proclamation, states america, seal, city washington, seal united, affix, cause seal, president united, hand cause
#
# Topic  166
# space, nasa, flight, exploration, mission, earth, launch, moon, satellite, crew
#
# Topic  167
# team, coach, game, win, player, football, season, fan, congratulation, sport
#
# Topic  168
# afghanistan, afghan, pakistan, taliban, troop, al, karzai, qaida, al qaida, support
#
# Topic  169
# california, los, angeles, los angeles, san, francisco, san francisco, diego, southern, ca
#
# Topic  170
# hoover, herbert, dear, wish, greeting, sympathy, extend, anniversary, express, sincerely
#
# Topic  171
# white, white house, house, president meet, assistant president, meet, congress united, conference, mondale, office
#
# Topic  172
# title, section title, title united, states code, code, section, vest, authority, authority vest, vest president
#
# Topic  173
# council, security council, chairman, price, national council, wage, policy, council resolution, security, advisory
#
# Topic  174
# war, secretary war, world war, army, end, fight, war ii, troop, end war, ii
#
# Topic  175
# snow, tony, talk, try, question, look, point, al qaeda, qaeda, fact
#
# Topic  176
# law, enforcement, law enforcement, firm, law firm, sign law, sign, law school, immigration, counsel
#
# Topic  177
# labor, dispute, railway, railroad, employee, board shall, carrier, board, act amend, andwhereas
#
# Topic  178
# cyprus, turkey, turkish, secretary general, settlement, greek, greece, general, effort, progress
#
# Topic  179
# department, department state, department commerce, commerce, department interior, department justice, department agency, justice, department defense, bureau
#
# Topic  180
# god, prayer, faith, day, pray, love, life, blessing, christmas, religious
#
# Topic  181
# determination, memorandum, authorize direct, federal register, register, assistance, direct, authorize, publish, presidential
#
# Topic  182
# russia, russian, ukraine, yeltsin, president yeltsin, putin, georgia, ukrainian, president putin, president clinton
#
# Topic  183
# kasich, ohio, john, marco, rubio, poll, republican, candidate, read, gop
#
# Topic  184
# carolina, south, south carolina, north carolina, north, dakota, south africa, primary, marco, georgia
#
# Topic  185
# poland, polish, solidarity, europe, eastern, missile defense, eastern europe, october, patriot, tie
#
# Topic  186
# panama, canal, colombia, hemisphere, nicaragua, zone, central, central america, caribbean, port
#
# Topic  187
# community, help, volunteer, initiative, support, organization, need, effort, youth, citizen
#
# Topic  188
# amendment, provision, constitution, passage, constitutional, seek, marriage, regulation, propose, require
#
# Topic  189
# indians, indian, interior, secretary interior, tribe, commissioner, communication, reservation, tribal, territory
#
# Topic  190
# land, monument, public land, acre, park, reserve, alaska, area, public, national park
#
# Topic  191
# air, force, air force, aircraft, task force, aviation, task, clean air, flight, pollution
#
# Topic  192
# service, civil service, civil, postal, post office, employee, examination, public service, post, office
#
# Topic  193
# act, provision, law act, act provide, sign, extend, president sign, authorize, authority, approve
#
# Topic  194
# report, congress united, accordance, william clinton, sincerely, william, attach, dear, congress, contain
#
# Topic  195
# honorable, delegation, ambassador, presidential, designation, today announce, attend, president barack, announce, lead
#
# Topic  196
# president announce, announce, announce intention, intention, intention nominate, nominate, intention appoint, morning president, afternoon president, travel
#
# Topic  197
# forest, october, resource, product, week, management, tree, october year, natural, agriculture
#
# Topic  198
# gingrich, newt, santorum, rick, conservative, candidate, speaker, perry, republican, debate
#
# Topic  199
# herewith, transmit herewith, transmit, communication, consideration, copy, senate house, congress united, cleveland, paper

# %%
# returns the index of topic(as in list of total topics) for given doc
def get_topic_index(doc,vectorizer, topic_model):
#lsa_tfidf.transform(tfidf_vectorizer.transform([docs[101456]])).argmax(axis=1)
    return topic_model.transform(vectorizer.transform([doc])).argmax(axis=1)[0]


#get_topic_index(docs[73159], tfidf_vectorizer, lsa_tfidf)

# %%
sample_president_docs={}
for president in presidents:
    sample_president_docs[president]=[]
for i in range(len(sample_docs)):
    if sample_authors[i] in presidents:
        sample_president_docs[sample_authors[i]].append(sample_docs[i])

# %%
sample_president_docs.keys()
# Out:
# dict_keys(['Donald J. Trump', 'Richard Nixon', 'John Adams', 'Lyndon B. Johnson', 'Dwight D. Eisenhower', 'Woodrow Wilson', 'Abraham Lincoln', 'John F. Kennedy', 'George W. Bush', 'Grover Cleveland', 'William J. Clinton', 'Franklin D. Roosevelt', 'James Madison', 'Ulysses S. Grant', 'Barack Obama', 'William Howard Taft', 'Andrew Jackson', 'George Bush', 'Ronald Reagan', 'Harry S. Truman', 'Gerald R. Ford', 'Herbert Hoover', 'George Washington', 'William Henry Harrison', 'Jimmy Carter', 'Warren G. Harding', 'Thomas Jefferson', 'Theodore Roosevelt'])

# %%
num_topics = 200
sample_president_topic_vecs=[]

for i in range(len(presidents)):
    sample_president_topic_vec = [0]*num_topics
    for doc in sample_president_docs[presidents[i]]:
        topic_label = get_topic_index(doc, sample_tfidf_vectorizer, sample_nmf_tfidf)
        sample_president_topic_vec[topic_label] = sample_president_topic_vec[topic_label]+1
    sample_president_topic_vecs.append(sample_president_topic_vec)

# %%
sample_president_topic_vecs[0][:10]
# Out:
# [35, 0, 12, 0, 11, 0, 0, 42, 2, 0]

# %%
sample_president_topic_vecs[1][:10]
# Out:
# [88, 0, 1, 46, 9, 0, 0, 2, 1, 9]

# %%
filename = '/home/ubuntu/proj4/data/sample_30000_nmf_200_tfidf_president_topics_vecs.pkl'
pickle.dump(sample_president_topic_vecs, open(filename, 'wb'))

# %%
filename = '/home/ubuntu/proj4/data/sample_30000_nmf_200_tfidf_sample_indices_.pkl'
pickle.dump(sample_docs_indices, open(filename, 'wb'))

# %%
filename = '/home/ubuntu/proj4/data/sample_30000_nmf_200_tfidf_sample_authors_docs_.pkl'
pickle.dump((sample_authors,sample_docs), open(filename, 'wb'))

# %%
def normalize_vec(vec):
    
    normalized_vec = vec
    sum_vec = sum(vec)
    
    for i in range(len(vec)):
        normalized_vec[i]=vec[i]/sum_vec
        
    return normalized_vec

# %%
normalized_sample_president_topic_vecs=[]
for i in range(len(sample_president_topic_vecs)):
    normalized_sample_president_topic_vecs.append(normalize_vec(sample_president_topic_vecs[i]))

# %%
len(set(normalized_sample_president_topic_vecs))
